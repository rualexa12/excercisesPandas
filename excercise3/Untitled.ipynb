# %% [markdown]
# <h1>EXERCISE 3</h1>
# <h2>convert a serie object to python list<h2>

# %%
import pandas as pd #get pandas library

# %% [markdown]
# <h3>SOLUTION<h3>

# %%
data = [1,3,5,6,8,13] #our data

s = pd.Series(data) #we create a serie Struture with our data
# Out:
# 0     1
# 1     3
# 2     5
# 3     6
# 4     8
# 5    13
# dtype: int64

# %%
print(type(kus))
print(list)

# %%
myList = s.tolist()
myList
# Out:
# [1, 3, 5, 6, 8, 13]
