# %% [markdown]
# <h1>EXERCISE 2</h1>
# <h2>create and display a one-dimensional array with a serie structure</h2>

# %%
import pandas as pd #get pandas library

# %% [markdown]
# <h3>SOLUTION</h3>

# %%
data = [1,3,5,6,8,13] #our data

s = pd.Series(data) #we create a serie Struture with our data
s
# Out:
# 0     1
# 1     3
# 2     5
# 3     6
# 4     8
# 5    13
# dtype: int64

# %%
s.size #we get the size of our serie
# Out:
# 6

# %%
s.describe()
# Out:
# count     6.000000
# mean      6.000000
# std       4.195235
# min       1.000000
# 25%       3.500000
# 50%       5.500000
# 75%       7.500000
# max      13.000000
# dtype: float64
